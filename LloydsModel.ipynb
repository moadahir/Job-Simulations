# %% [markdown]
# # Lloyds Banking Group - Customer Retention Model

# %% [markdown]
# This is a predictive model for customer churn at Lloyds Banking Group. I am predicting customer churn based on a dataset in Excel format, with 5 notebooks inside; Customer Demographics, Transaction History, Customer Service, Online Activity, and Churn Status.
#
# In order to successfully build this model, we will begin by selecting parts of the data that will be relevant for predicting customer churn, explain the rationale for my choice and ensure that the data will provide meaningful insights based on customer behavior. We will follow this up with exploring the data through EDA, visualising the data which would help us uncover trends and relationships between the selected features. We will then preprocess the data accordingly before finally selecting a model.

# %% [markdown]
# ### 1. Gathering the relevant data

# %% [markdown]
# Here is the data I have chosen, in no particular order, and why:
#
# 1. Age - older customers v youger customers
# 2. Gender - male v female
# 3. Marital Status - married v single v divorced v civil partnership
# 4. Income Level - low v medium v high
# 5. Amount Spent - how much they spend
# 6. Product Category - what they spend their money on
# 7. Interaction Type - inquiry / feedback / complaint
# 8. Resolution Status - resolved / unresolved
# 9. Login Frequency - how many times each customer has logged in
# 10. Service Usage - device used to log in
# 11. Churn Status - whether the customer has churned or not

# %% [markdown]
# ### 2. Exploratory Data Analysis

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 17.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 19.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 18.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 19.1 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

data = pd.read_excel('customer_churn_data_large.xlsx')
# Out:
# Matplotlib is building the font cache; this may take a moment.
